# %%
# pip install copernicusmarine

# %%
# Load from .env and pass credentials explicitly to subset()
import os
from dotenv import load_dotenv

load_dotenv()  # loads .env in current working directory

USERNAME = os.getenv("COPERNICUS_MARINE_USERNAME")
PASSWORD = os.getenv("COPERNICUS_MARINE_PASSWORD")

# %%
import copernicusmarine

# Create output directory
os.makedirs("raw_data", exist_ok=True)

# %%
output_path = "raw_data/thetao.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-thetao_anfc_0.083deg_P1D-m",
    variables=["thetao"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:10:08Z - Selected dataset version: "202406"
# INFO - 2025-11-15T14:10:08Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:10:13Z - Starting download. Please wait...
# INFO - 2025-11-15T14:10:30Z - Successfully downloaded to raw_data/thetao.nc
# Download completed: raw_data/thetao.nc

# %%
output_path = "raw_data/so.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-so_anfc_0.083deg_P1D-m",
    variables=["so"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:10:33Z - Selected dataset version: "202406"
# INFO - 2025-11-15T14:10:33Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:10:39Z - Starting download. Please wait...
# INFO - 2025-11-15T14:11:00Z - Successfully downloaded to raw_data/so.nc
# Download completed: raw_data/so.nc

# %%
output_path = "raw_data/currents.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-cur_anfc_0.083deg_P1D-m",
    variables=["uo", "vo"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:11:02Z - Selected dataset version: "202406"
# INFO - 2025-11-15T14:11:02Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:11:06Z - Starting download. Please wait...
# INFO - 2025-11-15T14:11:21Z - Successfully downloaded to raw_data/currents.nc
# Download completed: raw_data/currents.nc

# %%
output_path = "raw_data/wo.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-wcur_anfc_0.083deg_P1D-m",
    variables=["wo"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:11:24Z - Selected dataset version: "202406"
# INFO - 2025-11-15T14:11:24Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:11:29Z - Starting download. Please wait...
# INFO - 2025-11-15T14:11:51Z - Successfully downloaded to raw_data/wo.nc
# Download completed: raw_data/wo.nc

# %%
output_path = "raw_data/ph.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-car_anfc_0.25deg_P1D-m",
    variables=["ph"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:11:54Z - Selected dataset version: "202311"
# INFO - 2025-11-15T14:11:54Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:11:58Z - Starting download. Please wait...
# INFO - 2025-11-15T14:12:02Z - Successfully downloaded to raw_data/ph.nc
# Download completed: raw_data/ph.nc

# %%
output_path = "raw_data/spco2.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-co2_anfc_0.25deg_P1D-m",
    variables=["spco2"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    # minimum_depth=0.5,
    # maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:12:04Z - Selected dataset version: "202311"
# INFO - 2025-11-15T14:12:04Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:12:07Z - Starting download. Please wait...
# INFO - 2025-11-15T14:12:10Z - Successfully downloaded to raw_data/spco2.nc
# Download completed: raw_data/spco2.nc

# %%
output_path = "raw_data/nutrients.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-nut_anfc_0.25deg_P1D-m",
    variables=["fe", "no3", "po4", "si"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:12:12Z - Selected dataset version: "202311"
# INFO - 2025-11-15T14:12:12Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:12:18Z - Starting download. Please wait...
# INFO - 2025-11-15T14:12:40Z - Successfully downloaded to raw_data/nutrients.nc
# Download completed: raw_data/nutrients.nc

# %%
output_path = "raw_data/kd.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-optics_anfc_0.25deg_P1D-m",
    variables=["kd"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:12:43Z - Selected dataset version: "202311"
# INFO - 2025-11-15T14:12:43Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:12:48Z - Starting download. Please wait...
# INFO - 2025-11-15T14:12:52Z - Successfully downloaded to raw_data/kd.nc
# Download completed: raw_data/kd.nc

# %%
output_path = "raw_data/chl.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-pft_anfc_0.25deg_P1D-m",
    variables=["chl"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:12:55Z - Selected dataset version: "202311"
# INFO - 2025-11-15T14:12:55Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:12:59Z - Starting download. Please wait...
# INFO - 2025-11-15T14:13:03Z - Successfully downloaded to raw_data/chl.nc
# Download completed: raw_data/chl.nc

# %%
output_path = "raw_data/o2.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-bio_anfc_0.25deg_P1D-m",
    variables=["o2"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2023-11-15T00:00:00",
    end_datetime="2025-11-24T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-15T14:13:06Z - Selected dataset version: "202311"
# INFO - 2025-11-15T14:13:06Z - Selected dataset part: "default"
# INFO - 2025-11-15T14:13:09Z - Starting download. Please wait...
# INFO - 2025-11-15T14:13:12Z - Successfully downloaded to raw_data/o2.nc
# Download completed: raw_data/o2.nc
