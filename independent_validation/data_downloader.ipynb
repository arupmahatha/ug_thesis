# %%
# pip install copernicusmarine

# %%
# Load from .env and pass credentials explicitly to subset()
import os
from dotenv import load_dotenv

load_dotenv()  # loads .env in current working directory

USERNAME = os.getenv("COPERNICUS_MARINE_USERNAME")
PASSWORD = os.getenv("COPERNICUS_MARINE_PASSWORD")

# %%
import copernicusmarine

# Create output directory
os.makedirs("raw_data", exist_ok=True)

# %%
output_path = "raw_data/thetao.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-thetao_anfc_0.083deg_P1D-m",
    variables=["thetao"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:09:40Z - Selected dataset version: "202406"
# INFO - 2025-11-25T19:09:40Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:09:44Z - Starting download. Please wait...
# INFO - 2025-11-25T19:09:49Z - Successfully downloaded to raw_data/thetao.nc
# Download completed: raw_data/thetao.nc

# %%
output_path = "raw_data/so.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-so_anfc_0.083deg_P1D-m",
    variables=["so"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:09:52Z - Selected dataset version: "202406"
# INFO - 2025-11-25T19:09:52Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:09:56Z - Starting download. Please wait...
# INFO - 2025-11-25T19:10:02Z - Successfully downloaded to raw_data/so.nc
# Download completed: raw_data/so.nc

# %%
output_path = "raw_data/currents.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-cur_anfc_0.083deg_P1D-m",
    variables=["uo", "vo"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:10:05Z - Selected dataset version: "202406"
# INFO - 2025-11-25T19:10:05Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:10:08Z - Starting download. Please wait...
# INFO - 2025-11-25T19:10:26Z - Successfully downloaded to raw_data/currents.nc
# Download completed: raw_data/currents.nc

# %%
output_path = "raw_data/wo.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_phy-wcur_anfc_0.083deg_P1D-m",
    variables=["wo"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:10:30Z - Selected dataset version: "202406"
# INFO - 2025-11-25T19:10:30Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:10:33Z - Starting download. Please wait...
# INFO - 2025-11-25T19:10:38Z - Successfully downloaded to raw_data/wo.nc
# Download completed: raw_data/wo.nc

# %%
output_path = "raw_data/ph.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-car_anfc_0.25deg_P1D-m",
    variables=["ph"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:10:41Z - Selected dataset version: "202311"
# INFO - 2025-11-25T19:10:41Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:10:45Z - Starting download. Please wait...
# INFO - 2025-11-25T19:10:48Z - Successfully downloaded to raw_data/ph.nc
# Download completed: raw_data/ph.nc

# %%
output_path = "raw_data/spco2.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-co2_anfc_0.25deg_P1D-m",
    variables=["spco2"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    # minimum_depth=0.5,
    # maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:10:51Z - Selected dataset version: "202311"
# INFO - 2025-11-25T19:10:51Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:10:54Z - Starting download. Please wait...
# INFO - 2025-11-25T19:10:57Z - Successfully downloaded to raw_data/spco2.nc
# Download completed: raw_data/spco2.nc

# %%
output_path = "raw_data/nutrients.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-nut_anfc_0.25deg_P1D-m",
    variables=["fe", "no3", "po4", "si"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:11:00Z - Selected dataset version: "202311"
# INFO - 2025-11-25T19:11:00Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:11:03Z - Starting download. Please wait...
# INFO - 2025-11-25T19:11:11Z - Successfully downloaded to raw_data/nutrients.nc
# Download completed: raw_data/nutrients.nc

# %%
# output_path = "raw_data/kd.nc"

# # Subset call
# copernicusmarine.subset(
#     dataset_id="cmems_mod_glo_bgc-optics_anfc_0.25deg_P1D-m",
#     variables=["kd"],
#     minimum_longitude=87,
#     maximum_longitude=91,
#     minimum_latitude=20,
#     maximum_latitude=23,
#     start_datetime="2022-06-01T00:00:00",
#     end_datetime="2023-11-14T00:00:00",
#     minimum_depth=0.5,
#     maximum_depth=0.5,
#     output_filename=output_path,
#     username=USERNAME,
#     password=PASSWORD,
# )

# print("Download completed:", output_path)

# %%
output_path = "raw_data/chl.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-pft_anfc_0.25deg_P1D-m",
    variables=["chl"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:11:14Z - Selected dataset version: "202311"
# INFO - 2025-11-25T19:11:14Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:11:17Z - Starting download. Please wait...
# INFO - 2025-11-25T19:11:20Z - Successfully downloaded to raw_data/chl.nc
# Download completed: raw_data/chl.nc

# %%
output_path = "raw_data/o2.nc"

# Subset call
copernicusmarine.subset(
    dataset_id="cmems_mod_glo_bgc-bio_anfc_0.25deg_P1D-m",
    variables=["o2"],
    minimum_longitude=87,
    maximum_longitude=91,
    minimum_latitude=20,
    maximum_latitude=23,
    start_datetime="2022-06-01T00:00:00",
    end_datetime="2023-11-14T00:00:00",
    minimum_depth=0.5,
    maximum_depth=0.5,
    output_filename=output_path,
    username=USERNAME,
    password=PASSWORD,
)

print("Download completed:", output_path)
# Out:
# INFO - 2025-11-25T19:11:22Z - Selected dataset version: "202311"
# INFO - 2025-11-25T19:11:22Z - Selected dataset part: "default"
# INFO - 2025-11-25T19:11:25Z - Starting download. Please wait...
# INFO - 2025-11-25T19:11:28Z - Successfully downloaded to raw_data/o2.nc
# Download completed: raw_data/o2.nc
